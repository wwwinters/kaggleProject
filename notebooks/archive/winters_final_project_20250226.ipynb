# %% [markdown]
# -------------------------------------------------------
# - Wiley Winters
# - MSDS 686 Deep Learning
# - Week 7-8 Kaggle Project&nbsp;&mdash;&nbsp;Brain Tumor Classification
# - 2025-MAR-
# --------------------------------------------------------

# %% [markdown]
# ## Requirements

# %% [markdown]
# ----------------------------------------------
# ### Required for 80%
# Complete project on *kaggle.com* using the skills learned in the <u>Deep Learning</u> class.  The following are required:
# - Show/plot sample images or data with labels
# - Include at least on of the following
#   - Convolution
#   - Max Pooling
#   - Batch Normalization
#   - Dropout
#   - LSTM
#   - TF-IDf
# - Use validation data
# - Evaluate model on test data

# %% [markdown]
# -------------------------------------------
# ### Additional for another 20%
# - Use data augmentation
# - Use at least one of the following:
#   - Kernels
#   - Activation functions
#   - Loss functions
#   - Libraries
#   - Methods
# - Learning rate optimization
# - Functional API model
# - Transfer learning with or without trainable parameters
# - Confusion matrix and / or ROC plots
# - Plots of accuracy/loss vs epochs
# - Show/plot sample incorrect prediction with labels and correct label

# %% [markdown]
# ----------------------------------------------------------------
# ## Load Libraries and Packages

# %%
# General Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, logging, random

# Data prep and model scoring
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score
from sklearn.metrics import precision_recall_curve, auc

# TensorFlow likes to display a lot of debug information
# on my home system
# I will squash the messages
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
logging.getLogger('tensorFlow').setLevel(logging.FATAL)

# tensorflow and keras' API
import tensorflow as tf
from tensorflow import keras

# Model building
from keras.applications import Xception
from tensorflow.keras import backend
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Input, Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Model architecture visualization
from visualkeras import layered_view

# Model training
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import Precision, Recall

# Make plots have guidelines
plt.style.use('ggplot')

# Squash Python warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740655572.541027  445062 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740655572.546520  445062 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %% [markdown]
# ### Set Random Seed for Reproducibility

# %%
tf.keras.utils.set_random_seed(42)
tf.random.set_seed(42)
np.random.seed(42)
random.seed(42)

# %% [markdown]
# ### Declare Global Variables

# %%
# Define training and testing image directories
home_dir = '/home/wiley'
trn_dir = home_dir+'/regis/dataScience/kaggleProject/images/data/training'
tst_dir = home_dir+'/regis/dataScience/kaggleProject/images/data/testing'

#home_dir = '/disk01/e384698'
#trn_dir = home_dir+'/msds686/week7/images/data/training/'
#tst_dir = home_dir+'/msds686/week7/images/data/testing/'

# Define classes
classes = ['negative', 'positive']

# Define early_stop callback
early_stop = EarlyStopping(monitor='val_loss', min_delta=1e-9, patience=8,
                           restore_best_weights=True)

# Define reduce LR on Plateau callback
reduceLRO = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=5,
                              min_delta=0.0001, min_lr=0,
                              restore_best_weights=True)

# Image size and shape
img_size = (224, 224)
img_shape = (224, 224, 3)

# Number of classes
num_classes = 2

# %% [markdown]
# ## Define Functions

# %% [markdown]
# ### Load DataFrames
# - Join image filename and path information
# - Create labels from class directory names
# - Create dataframe
# - Randomize dataframe rows

# %%
def load_dataframe(path):
    labels, paths = zip(*[(label, os.path.join(path, label, image))
                        for label in os.listdir(path)
                        if os.path.isdir(os.path.join(path, label))
                        for image in os.listdir(os.path.join(path, label))])

    df = pd.DataFrame({'paths': paths, 'labels': labels})
    df = df.sample(frac=1, random_state=42).reset_index(drop=True)
    
    return df

# %% [markdown]
# ### Plot Performance Metrics
# Plot the following:
# - Training loss
# - Validation loss
# - Training Precision
# - Validation Precision
# - Training Recall
# - Validation Recall

# %%
def plot_history(history):
    epochs = range(1, len(history.history['accuracy']) + 1)
    plt.figure(figsize=(20,12))

    # Plot training and validation loss
    plt.subplot(2,2,1)
    plt.plot(epochs, history.history['loss'], 'b', label = 'Training Loss')
    plt.plot(epochs, history.history['val_loss'], 'r', label = 'Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot training and validation accuracy
    plt.subplot(2,2,2)
    plt.plot(epochs, history.history['accuracy'], 'b', label = 'Training Accuracy')
    plt.plot(epochs, history.history['val_accuracy'], 'r', label = 'Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot training and validation precision
    plt.subplot(2,2,3)
    plt.plot(epochs, history.history['precision'], 'b', label='Training Precision')
    plt.plot(epochs, history.history['val_precision'], 'r', label='Validation Precision')
    plt.title('Training and Validation Precision')
    plt.xlabel('Epochs')
    plt.ylabel('Precision')
    plt.legend()

    # Plot training and validation recall
    plt.subplot(2,2,4)
    plt.plot(epochs, history.history['recall'], 'b', label='Training Recall')
    plt.plot(epochs, history.history['val_recall'], 'r', label='Validation Recall')
    plt.title('Training and Validation Recall')
    plt.xlabel('Epochs')
    plt.ylabel('Recall')
    plt.legend()

    plt.suptitle('Model Training Metrics over Epochs', fontsize=16)
    plt.show()

    # Plot training and validation AUPRC
    plt.figure(figsize=(5,3))
    plt.plot(epochs, history.history['auprc'], 'b', label='Training AUPRC')
    plt.plot(epochs, history.history['val_auprc'], 'r', label='Validation AUPRC')
    plt.title('Training and Validation AUPRC')
    plt.xlabel('Epochs')
    plt.ylabel('AUPRC')
    plt.legend()
    plt.show()

# %% [markdown]
# ### Evaluate Model's Performance on Test Data
# - Compute accuracy and loss
# - Compute AUPRC (**A**rea **U**under the **P**recision&nbsp;&mdash;&nbsp;**R**ecall score)
# - Compute ROC AUC Scores

# %%
def score_model(model, trn_ds, tst_ds):
    my_model = model
    prediction = my_model.predict(tst_ds)
    train_score = my_model.score(trn_ds)
    accur_score = accuracy_score(tst_ds, prediction)
    f1 = f1_score(tst_ds, prediction)
    roc_score = roc_auc_score(tst_ds, prediction)
    cm = confusion_matrix(tst_ds, prediction).flatten()
    
    print(f'Model:          {my_model}')
    print(f'Train Score:    {train_score}')
    print(f'Accuracy Score: {accur_score}')
    print(f'F1 score:       {f1}')
    print(f'ROC AUC Score:  {roc_score}')
    print(f'Confusion:      {cm}')
    
    return prediction

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Create and Load DataFrame for EDA

# %%
# Load training data
trn_df = load_dataframe(trn_dir)

# Load testing data
tst_df = load_dataframe(tst_dir)

# Take a look at the results
print('Training:   \n', trn_df.head(10).to_markdown())
print('Testing:    \n', tst_df.head(10).to_markdown())
# Out:
# Training:
#  |    | paths                                                                                                   | labels   |
# |---:|:--------------------------------------------------------------------------------------------------------|:---------|
# |  0 | /home/wiley/regis/dataScience/kaggleProject/images/data/training/positive/TCGA_HT_7881_19981015_39.tif  | positive |
# |  1 | /home/wiley/regis/dataScience/kaggleProject/images/data/training/negative/Te-me_0244.jpg                | negative |
# |  2 | /home/wiley/regis/dataScience/kaggleProject/images/data/training/positive/TCGA_DU_8167_19970402_19.tif  | positive |
# |  3 | /home/wiley/regis/dataScience/kaggleProject/images/data/training/negative/Tr-no_1073.jpg                | negative |
# |  4 | /home/wiley/regis/dataScience/kaggleProject/images/data/training/negative/Tr-no_0417.jpg                | negative |
# |  5 | /home/wiley/regis/dataScience/kaggleProject/images/data/training/negative/Tr-pi_0984.jpg                | negative |
# |  6 | /home/wiley/regis/dataScience/kaggleProject/images/data/training/positive/Tr-gl_0820.jpg                | positive |
# |  7 | /home/wiley/regis/dataScience/kaggleProject/images/data/training/positive/TCGA_DU_6401_19831001_27.tif  | positive |
# |  8 | /home/wiley/regis/dataScience/kaggleProject/images/data/training/negative/OAS2_0022_MR1_y_slice_134.jpg | negative |
# |  9 | /home/wiley/regis/dataScience/kaggleProject/images/data/training/positive/TCGA_HT_7860_19960513_11.tif  | positive |
# Testing:
#  |    | paths                                                                                                  | labels   |
# |---:|:-------------------------------------------------------------------------------------------------------|:---------|
# |  0 | /home/wiley/regis/dataScience/kaggleProject/images/data/testing/positive/Tr-gl_0933.jpg                | positive |
# |  1 | /home/wiley/regis/dataScience/kaggleProject/images/data/testing/positive/Tr-me_0423.jpg                | positive |
# |  2 | /home/wiley/regis/dataScience/kaggleProject/images/data/testing/positive/TCGA_HT_A61A_20000127_25.tif  | positive |
# |  3 | /home/wiley/regis/dataScience/kaggleProject/images/data/testing/negative/Tr-pi_0895.jpg                | negative |
# |  4 | /home/wiley/regis/dataScience/kaggleProject/images/data/testing/positive/Tr-me_1202.jpg                | positive |
# |  5 | /home/wiley/regis/dataScience/kaggleProject/images/data/testing/negative/OAS2_0112_MR1_z_slice_105.jpg | negative |
# |  6 | /home/wiley/regis/dataScience/kaggleProject/images/data/testing/negative/OAS2_0105_MR1_z_slice_145.jpg | negative |
# |  7 | /home/wiley/regis/dataScience/kaggleProject/images/data/testing/positive/Tr-me_0197.jpg                | positive |
# |  8 | /home/wiley/regis/dataScience/kaggleProject/images/data/testing/negative/OAS2_0020_MR1_z_slice_138.jpg | negative |
# |  9 | /home/wiley/regis/dataScience/kaggleProject/images/data/testing/positive/TCGA_FG_7643_20021104_16.tif  | positive |

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Look at Training Images' Distribution

# %%
plt.figure(figsize=(6,4))
trn_df['labels'].value_counts().plot(kind='bar')
plt.title('Distribution of Image Counts in Training Data')
plt.xlabel('Category')
plt.ylabel('Image Count')
plt.show()

# %% [markdown]
# Positive images slightly outnumber the negative ones, but are close enough to continue without additional data wrangling

# %% [markdown]
# ### Look at Testing Images' Distribution

# %%
plt.figure(figsize=(6,4))
tst_df['labels'].value_counts().plot(kind='bar')
plt.title('Distribution of Image Counts in Testing Data')
plt.xlabel('Category')
plt.ylabel('Image Count')
plt.show()

# %% [markdown]
# Distribution mirrors what the *training data* shows, but with less frequency.

# %% [markdown]
# ### Examine Shape of Training and Testing DataFrames

# %%
print('Training Shape: \n', trn_df.shape)
print('Testing Shape:  \n', tst_df.shape)
# Out:
# Training Shape:
#  (13106, 2)
# Testing Shape:
#  (3276, 2)

# %% [markdown]
# **NOTE:**&nbsp;&nbsp;Since the dataframes are built from the contents of the image directories, there should be no missing values or duplicates.

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Create a Validation Subset from Training Data
# I will use `flow_from_dataframe()` to create datasets for model training; therefore, no reason to create a new directory structure for validation data

# %%
val_df, trn_df = train_test_split(trn_df, train_size=0.2, random_state=42,
                                  stratify=trn_df['labels'])
val_df.sample(10)
# Out:
#                                                    paths    labels
# 4171   /home/wiley/regis/dataScience/kaggleProject/im...  positive
# 11066  /home/wiley/regis/dataScience/kaggleProject/im...  positive
# 6446   /home/wiley/regis/dataScience/kaggleProject/im...  positive
# 10366  /home/wiley/regis/dataScience/kaggleProject/im...  positive
# 10099  /home/wiley/regis/dataScience/kaggleProject/im...  positive
# 4255   /home/wiley/regis/dataScience/kaggleProject/im...  positive
# 6141   /home/wiley/regis/dataScience/kaggleProject/im...  positive
# 381    /home/wiley/regis/dataScience/kaggleProject/im...  positive
# 1675   /home/wiley/regis/dataScience/kaggleProject/im...  negative
# 12140  /home/wiley/regis/dataScience/kaggleProject/im...  positive

# %% [markdown]
# ## Process Images from DataFrames

# %%
bs = 32

gen = ImageDataGenerator(brightness_range=(0.5, 1.5),
                         rotation_range=20,
                         width_shift_range=0.2,
                         height_shift_range=0.2,
                         shear_range=0.2,
                         zoom_range=0.2)

tst_gen = ImageDataGenerator(rescale=1./255)

trn_gen = gen.flow_from_dataframe(trn_df, x_col='paths', y_col='labels',
                                  batch_size=bs, target_size=img_size,
                                  shuffle=True)

val_gen = gen.flow_from_dataframe(val_df, x_col='paths', y_col='labels',
                                  batch_size=bs, target_size=img_size,
                                  shuffle=True)

tst_gen = tst_gen.flow_from_dataframe(tst_df, x_col='paths', y_col='labels',
                                      batch_size=16, target_size=img_size,
                                      shuffle=False)
# Out:
# Found 10485 validated image filenames belonging to 2 classes.
# Found 2621 validated image filenames belonging to 2 classes.
# Found 3276 validated image filenames belonging to 2 classes.

# %% [markdown]
# ## Examine a few Images and their Labels

# %%
dict = trn_gen.class_indices
classes = list(dict.keys())
images, labels = next(tst_gen)

plt.figure(figsize=(20,20))
for i, (image, label) in enumerate(zip(images, labels)):
    plt.subplot(4,4,i+1)
    plt.imshow(image)
    class_name = classes[np.argmax(label)]
    plt.title(class_name, color='k', fontsize=15)

plt.show()

# %% [markdown]
# ### Configure Training Values

# %%
# Initial batch size
batch_size = 64

# Number of training epochs
epochs = 50

# Steps per epoch
steps_per_ep = trn_gen.samples // batch_size

# Validation steps
val_steps = tst_gen.samples // batch_size

print(f'Image shape:      {img_shape}')
print(f'Epochs:           {epochs}')
print(f'Batch size:       {batch_size}')
print(f'Steps per epoch:  {steps_per_ep}')
print(f'Validation steps: {val_steps}')
# Out:
# Image shape:      (224, 224, 3)
# Epochs:           50
# Batch size:       64
# Steps per epoch:  163
# Validation steps: 51

# %% [markdown]
# ## Baseline Model
# ### Define Model's Architecture

# %%
backend.clear_session()

inputs  = Input(shape=(img_shape))

# Conv Layer 1
conv1   = Conv2D(filters=32, kernel_size=4, padding='same',
                 activation='relu')(inputs)
pool1   = MaxPooling2D()(conv1)

# Conv Layer 2
conv2   = Conv2D(filters=64, kernel_size=4, padding='same',
                 activation='relu')(pool1)
pool2   = MaxPooling2D()(conv2)

# Conv Layer 3
conv3   = Conv2D(filters=128, kernel_size=4, padding='same',
                 activation='relu')(pool2)
pool3   = MaxPooling2D()(conv3)

# Apply Batch Normalization, Flatten, and Dense Layers
batch3  = BatchNormalization()(pool3)
flatten = Flatten()(batch3)
dense1   = Dense(128, activation='relu')(flatten)
dropout = Dropout(0,5)(dense1)
dense2   = Dense(512, activation='relu')(dropout)

# Pull the model together
preds   = Dense(num_classes, activation='softmax')(dense1)

model_base = Model(inputs, preds)

model_base.summary()
# Out:
# I0000 00:00:1740655619.763156  445062 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9629 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:09:00.0, compute capability: 8.9
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │         1,568 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 100352)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    12,845,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           258 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,011,554 (49.64 MB)
#  Trainable params: 13,011,298 (49.63 MB)
#  Non-trainable params: 256 (1.00 KB)

# %% [markdown]
# ### Visualize Layers

# %%
layered_view(model_base, legend=True, max_xy=300)
# Out:
# <PIL.Image.Image image mode=RGBA size=774x438>

# %% [markdown]
# ### Compile and Train Model

# %%
# Compile base model
model_base.compile(optimizer='Adam', loss='categorical_crossentropy',
                   metrics=['accuracy', Precision(), Recall(),
                            tf.keras.metrics.AUC(curve='PR', name='auprc')])

hist_base = model_base.fit(trn_gen, steps_per_epoch=steps_per_ep, epochs=epochs,
                           validation_data=val_gen,
                           validation_steps=val_steps,
                           callbacks=[early_stop, reduceLRO])
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740655631.341982  445211 service.cc:148] XLA service 0x7f9e1400eb80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1740655631.342006  445211 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# I0000 00:00:1740655631.624433  445211 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/163 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.5625 - auprc: 0.5486 - loss: 7.6310 - precision: 0.5625 - recall: 0.5625
# I0000 00:00:1740655636.222761  445211 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 77s 435ms/step - accuracy: 0.6533 - auprc: 0.6928 - loss: 2.5261 - precision: 0.6533 - recall: 0.6533 - val_accuracy: 0.7096 - val_auprc: 0.7466 - val_loss: 1.3937 - val_precision: 0.7096 - val_recall: 0.7096 - learning_rate: 0.0010
# Epoch 2/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 58s 356ms/step - accuracy: 0.7357 - auprc: 0.8418 - loss: 0.4975 - precision: 0.7357 - recall: 0.7357 - val_accuracy: 0.7503 - val_auprc: 0.8297 - val_loss: 0.7508 - val_precision: 0.7503 - val_recall: 0.7503 - learning_rate: 0.0010
# Epoch 3/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - accuracy: 0.8276 - auprc: 0.8932 - loss: 0.4175 - precision: 0.8276 - recall: 0.8276 - val_accuracy: 0.7365 - val_auprc: 0.8399 - val_loss: 0.6102 - val_precision: 0.7365 - val_recall: 0.7365 - learning_rate: 0.0010
# Epoch 4/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 58s 356ms/step - accuracy: 0.7622 - auprc: 0.8614 - loss: 0.5075 - precision: 0.7622 - recall: 0.7622 - val_accuracy: 0.6633 - val_auprc: 0.7530 - val_loss: 1.9121 - val_precision: 0.6633 - val_recall: 0.6633 - learning_rate: 0.0010
# Epoch 5/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 399ms/step - accuracy: 0.7728 - auprc: 0.8728 - loss: 0.4439 - precision: 0.7728 - recall: 0.7728 - val_accuracy: 0.7328 - val_auprc: 0.8406 - val_loss: 0.5280 - val_precision: 0.7328 - val_recall: 0.7328 - learning_rate: 0.0010
# Epoch 6/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.8748 - auprc: 0.9613 - loss: 0.2745 - precision: 0.8748 - recall: 0.8748 - val_accuracy: 0.6997 - val_auprc: 0.8123 - val_loss: 0.6857 - val_precision: 0.6997 - val_recall: 0.6997 - learning_rate: 0.0010
# Epoch 7/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 65s 397ms/step - accuracy: 0.7777 - auprc: 0.8824 - loss: 0.4321 - precision: 0.7777 - recall: 0.7777 - val_accuracy: 0.7292 - val_auprc: 0.8285 - val_loss: 0.5798 - val_precision: 0.7292 - val_recall: 0.7292 - learning_rate: 0.0010
# Epoch 8/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 57s 350ms/step - accuracy: 0.7992 - auprc: 0.9038 - loss: 0.3826 - precision: 0.7992 - recall: 0.7992 - val_accuracy: 0.8028 - val_auprc: 0.9079 - val_loss: 0.3799 - val_precision: 0.8028 - val_recall: 0.8028 - learning_rate: 0.0010
# Epoch 9/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 15s 92ms/step - accuracy: 0.7350 - auprc: 0.8543 - loss: 0.4722 - precision: 0.7350 - recall: 0.7350 - val_accuracy: 0.7721 - val_auprc: 0.8790 - val_loss: 0.4288 - val_precision: 0.7721 - val_recall: 0.7721 - learning_rate: 0.0010
# Epoch 10/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 58s 353ms/step - accuracy: 0.8089 - auprc: 0.9031 - loss: 0.3824 - precision: 0.8089 - recall: 0.8089 - val_accuracy: 0.8079 - val_auprc: 0.9116 - val_loss: 0.3796 - val_precision: 0.8079 - val_recall: 0.8079 - learning_rate: 0.0010
# Epoch 11/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 63s 386ms/step - accuracy: 0.8095 - auprc: 0.9106 - loss: 0.3664 - precision: 0.8095 - recall: 0.8095 - val_accuracy: 0.8088 - val_auprc: 0.9031 - val_loss: 0.3823 - val_precision: 0.8088 - val_recall: 0.8088 - learning_rate: 0.0010
# Epoch 12/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.8750 - auprc: 0.9441 - loss: 0.3278 - precision: 0.8750 - recall: 0.8750 - val_accuracy: 0.8301 - val_auprc: 0.9226 - val_loss: 0.3507 - val_precision: 0.8301 - val_recall: 0.8301 - learning_rate: 0.0010
# Epoch 13/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 63s 385ms/step - accuracy: 0.7771 - auprc: 0.8843 - loss: 0.5049 - precision: 0.7771 - recall: 0.7771 - val_accuracy: 0.6072 - val_auprc: 0.7183 - val_loss: 1.1739 - val_precision: 0.6072 - val_recall: 0.6072 - learning_rate: 0.0010
# Epoch 14/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 57s 354ms/step - accuracy: 0.7862 - auprc: 0.8847 - loss: 0.4282 - precision: 0.7862 - recall: 0.7862 - val_accuracy: 0.7381 - val_auprc: 0.8534 - val_loss: 0.5161 - val_precision: 0.7381 - val_recall: 0.7381 - learning_rate: 0.0010
# Epoch 15/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 15s 95ms/step - accuracy: 0.8439 - auprc: 0.9452 - loss: 0.3122 - precision: 0.8439 - recall: 0.8439 - val_accuracy: 0.7347 - val_auprc: 0.8461 - val_loss: 0.6019 - val_precision: 0.7347 - val_recall: 0.7347 - learning_rate: 0.0010
# Epoch 16/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 57s 352ms/step - accuracy: 0.8069 - auprc: 0.8993 - loss: 0.3943 - precision: 0.8069 - recall: 0.8069 - val_accuracy: 0.7583 - val_auprc: 0.8792 - val_loss: 0.4793 - val_precision: 0.7583 - val_recall: 0.7583 - learning_rate: 0.0010
# Epoch 17/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 64s 393ms/step - accuracy: 0.8090 - auprc: 0.9096 - loss: 0.3682 - precision: 0.8090 - recall: 0.8090 - val_accuracy: 0.8156 - val_auprc: 0.9119 - val_loss: 0.3591 - val_precision: 0.8156 - val_recall: 0.8156 - learning_rate: 0.0010
# Epoch 18/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 9s 56ms/step - accuracy: 0.7807 - auprc: 0.9129 - loss: 0.3629 - precision: 0.7807 - recall: 0.7807 - val_accuracy: 0.8301 - val_auprc: 0.9234 - val_loss: 0.3457 - val_precision: 0.8301 - val_recall: 0.8301 - learning_rate: 3.0000e-04
# Epoch 19/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 63s 388ms/step - accuracy: 0.8074 - auprc: 0.9085 - loss: 0.3646 - precision: 0.8074 - recall: 0.8074 - val_accuracy: 0.8070 - val_auprc: 0.9097 - val_loss: 0.3848 - val_precision: 0.8070 - val_recall: 0.8070 - learning_rate: 3.0000e-04
# Epoch 20/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 56s 343ms/step - accuracy: 0.8219 - auprc: 0.9138 - loss: 0.3585 - precision: 0.8219 - recall: 0.8219 - val_accuracy: 0.7927 - val_auprc: 0.9032 - val_loss: 0.3963 - val_precision: 0.7927 - val_recall: 0.7927 - learning_rate: 3.0000e-04
# Epoch 21/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 15s 94ms/step - accuracy: 0.8591 - auprc: 0.9263 - loss: 0.3386 - precision: 0.8591 - recall: 0.8591 - val_accuracy: 0.8119 - val_auprc: 0.9056 - val_loss: 0.3829 - val_precision: 0.8119 - val_recall: 0.8119 - learning_rate: 3.0000e-04
# Epoch 22/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 56s 344ms/step - accuracy: 0.8131 - auprc: 0.9116 - loss: 0.3594 - precision: 0.8131 - recall: 0.8131 - val_accuracy: 0.8392 - val_auprc: 0.9259 - val_loss: 0.3349 - val_precision: 0.8392 - val_recall: 0.8392 - learning_rate: 3.0000e-04
# Epoch 23/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 63s 388ms/step - accuracy: 0.8202 - auprc: 0.9152 - loss: 0.3592 - precision: 0.8202 - recall: 0.8202 - val_accuracy: 0.8211 - val_auprc: 0.9232 - val_loss: 0.3357 - val_precision: 0.8211 - val_recall: 0.8211 - learning_rate: 3.0000e-04
# Epoch 24/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.7809 - auprc: 0.8949 - loss: 0.4012 - precision: 0.7809 - recall: 0.7809 - val_accuracy: 0.8210 - val_auprc: 0.9139 - val_loss: 0.3644 - val_precision: 0.8210 - val_recall: 0.8210 - learning_rate: 3.0000e-04
# Epoch 25/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 63s 390ms/step - accuracy: 0.8055 - auprc: 0.9093 - loss: 0.3622 - precision: 0.8055 - recall: 0.8055 - val_accuracy: 0.8260 - val_auprc: 0.9205 - val_loss: 0.3486 - val_precision: 0.8260 - val_recall: 0.8260 - learning_rate: 3.0000e-04
# Epoch 26/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 57s 353ms/step - accuracy: 0.8159 - auprc: 0.9127 - loss: 0.3575 - precision: 0.8159 - recall: 0.8159 - val_accuracy: 0.8241 - val_auprc: 0.9248 - val_loss: 0.3359 - val_precision: 0.8241 - val_recall: 0.8241 - learning_rate: 3.0000e-04
# Epoch 27/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 15s 93ms/step - accuracy: 0.8438 - auprc: 0.9360 - loss: 0.3286 - precision: 0.8438 - recall: 0.8438 - val_accuracy: 0.8162 - val_auprc: 0.9213 - val_loss: 0.3439 - val_precision: 0.8162 - val_recall: 0.8162 - learning_rate: 3.0000e-04
# Epoch 28/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 57s 350ms/step - accuracy: 0.8256 - auprc: 0.9194 - loss: 0.3492 - precision: 0.8256 - recall: 0.8256 - val_accuracy: 0.8372 - val_auprc: 0.9317 - val_loss: 0.3135 - val_precision: 0.8372 - val_recall: 0.8372 - learning_rate: 9.0000e-05
# Epoch 29/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 61s 373ms/step - accuracy: 0.8320 - auprc: 0.9225 - loss: 0.3407 - precision: 0.8320 - recall: 0.8320 - val_accuracy: 0.8192 - val_auprc: 0.9208 - val_loss: 0.3414 - val_precision: 0.8192 - val_recall: 0.8192 - learning_rate: 9.0000e-05
# Epoch 30/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - accuracy: 0.8125 - auprc: 0.9046 - loss: 0.3735 - precision: 0.8125 - recall: 0.8125 - val_accuracy: 0.8170 - val_auprc: 0.9116 - val_loss: 0.3732 - val_precision: 0.8170 - val_recall: 0.8170 - learning_rate: 9.0000e-05
# Epoch 31/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 63s 386ms/step - accuracy: 0.8218 - auprc: 0.9228 - loss: 0.3383 - precision: 0.8218 - recall: 0.8218 - val_accuracy: 0.8284 - val_auprc: 0.9240 - val_loss: 0.3406 - val_precision: 0.8284 - val_recall: 0.8284 - learning_rate: 9.0000e-05
# Epoch 32/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 55s 341ms/step - accuracy: 0.8289 - auprc: 0.9179 - loss: 0.3467 - precision: 0.8289 - recall: 0.8289 - val_accuracy: 0.8291 - val_auprc: 0.9256 - val_loss: 0.3395 - val_precision: 0.8291 - val_recall: 0.8291 - learning_rate: 9.0000e-05
# Epoch 33/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 15s 91ms/step - accuracy: 0.8748 - auprc: 0.9365 - loss: 0.3129 - precision: 0.8748 - recall: 0.8748 - val_accuracy: 0.8100 - val_auprc: 0.9149 - val_loss: 0.3471 - val_precision: 0.8100 - val_recall: 0.8100 - learning_rate: 9.0000e-05
# Epoch 34/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 56s 344ms/step - accuracy: 0.8033 - auprc: 0.9093 - loss: 0.3596 - precision: 0.8033 - recall: 0.8033 - val_accuracy: 0.8392 - val_auprc: 0.9245 - val_loss: 0.3375 - val_precision: 0.8392 - val_recall: 0.8392 - learning_rate: 2.7000e-05
# Epoch 35/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 62s 383ms/step - accuracy: 0.8305 - auprc: 0.9247 - loss: 0.3324 - precision: 0.8305 - recall: 0.8305 - val_accuracy: 0.8419 - val_auprc: 0.9318 - val_loss: 0.3225 - val_precision: 0.8419 - val_recall: 0.8419 - learning_rate: 2.7000e-05
# Epoch 36/50
# 163/163 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.8441 - auprc: 0.9334 - loss: 0.3235 - precision: 0.8441 - recall: 0.8441 - val_accuracy: 0.8423 - val_auprc: 0.9311 - val_loss: 0.3194 - val_precision: 0.8423 - val_recall: 0.8423 - learning_rate: 2.7000e-05

# %%
plot_history(hist_base)

# %%
hist_df = pd.DataFrame(hist_base.history)
hist_df.tail()

# %%
model_base.evaluate(tst_gen, verbose=1)

# %%
# Get predictions
trn_pred = np.argmax(np.round(model_base.predict(trn_gen)), axis=1)
tst_pred = np.argmax(np.round(model_base.predict(tst_gen)), axis=1)

# Produce confusion matrix
trn_cm = confusion_matrix(trn_gen.classes, trn_pred)
tst_cm = confusion_matrix(tst_gen.classes, tst_pred)

print(f'Training Confusion Matrix:\n {trn_cm}')
print(f'Testing Confusion Matrix:\n {tst_cm}')
